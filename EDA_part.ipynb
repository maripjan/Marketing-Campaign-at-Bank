# %%
# Import libraries for data analysis
import pandas as pd
from summarytools import dfSummary

# Import libraries for data visualization
import seaborn as sns
import matplotlib.pyplot as plt

# Other libraries
import warnings
import custom_functions as cf
import json

# Set pandas options
#pd.set_option('future.no_silent_downcasting', True)
pd.set_option('display.max_columns', None)

# Ignore warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### Part I: Exploratory Data Analysis
#
# This part of my work mainly focuses on understanding the underlying data and various relationships between different attributes

# %%
df = pd.read_csv('data/train_file.csv')
df.sample(n=5)
# Out:
#        age         job   marital            education  default  housing  \
# 21513   44   housemaid   married          high.school       no       no
# 17594   38  technician  divorced  professional.course       no      yes
# 30887   61     retired   married          high.school       no  unknown
# 7009    43  management   married    university.degree       no       no
# 12414   32      admin.    single    university.degree  unknown      yes
#
#           loan    contact month day_of_week  duration  campaign  previous  \
# 21513       no   cellular   nov         fri       144         6         1
# 17594      yes  telephone   may         fri        78         3         0
# 30887  unknown  telephone   jun         wed        99         4         0
# 7009        no   cellular   nov         mon       179         1         0
# 12414      yes   cellular   aug         mon       128         2         0
#
#           poutcome   y
# 21513      failure  no
# 17594  nonexistent  no
# 30887  nonexistent  no
# 7009   nonexistent  no
# 12414  nonexistent  no

# %%
dfSummary(data=df, is_collapsible=True)
# Out:
# <button type="button" class = "st-collapsible",
#     id = "btn-6684" onclick = "coll_toggle_6684()">Show Summary - df</button>
#     <div class="st-content" id="cont-6684">
#       <style type="text/css">
# #T_d57bf thead>tr>th {
#   text-align: left;
# }
# #T_d57bf_row0_col0, #T_d57bf_row1_col0, #T_d57bf_row2_col0, #T_d57bf_row3_col0, #T_d57bf_row4_col0, #T_d57bf_row5_col0, #T_d57bf_row6_col0, #T_d57bf_row7_col0, #T_d57bf_row8_col0, #T_d57bf_row9_col0, #T_d57bf_row10_col0, #T_d57bf_row11_col0, #T_d57bf_row12_col0, #T_d57bf_row13_col0, #T_d57bf_row14_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_d57bf_row0_col1, #T_d57bf_row1_col1, #T_d57bf_row2_col1, #T_d57bf_row3_col1, #T_d57bf_row4_col1, #T_d57bf_row5_col1, #T_d57bf_row6_col1, #T_d57bf_row7_col1, #T_d57bf_row8_col1, #T_d57bf_row9_col1, #T_d57bf_row10_col1, #T_d57bf_row11_col1, #T_d57bf_row12_col1, #T_d57bf_row13_col1, #T_d57bf_row14_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_d57bf_row0_col2, #T_d57bf_row1_col2, #T_d57bf_row2_col2, #T_d57bf_row3_col2, #T_d57bf_row4_col2, #T_d57bf_row5_col2, #T_d57bf_row6_col2, #T_d57bf_row7_col2, #T_d57bf_row8_col2, #T_d57bf_row9_col2, #T_d57bf_row10_col2, #T_d57bf_row11_col2, #T_d57bf_row12_col2, #T_d57bf_row13_col2, #T_d57bf_row14_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_d57bf_row0_col3, #T_d57bf_row1_col3, #T_d57bf_row2_col3, #T_d57bf_row3_col3, #T_d57bf_row4_col3, #T_d57bf_row5_col3, #T_d57bf_row6_col3, #T_d57bf_row7_col3, #T_d57bf_row8_col3, #T_d57bf_row9_col3, #T_d57bf_row10_col3, #T_d57bf_row11_col3, #T_d57bf_row12_col3, #T_d57bf_row13_col3, #T_d57bf_row14_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_d57bf_row0_col4, #T_d57bf_row1_col4, #T_d57bf_row2_col4, #T_d57bf_row3_col4, #T_d57bf_row4_col4, #T_d57bf_row5_col4, #T_d57bf_row6_col4, #T_d57bf_row7_col4, #T_d57bf_row8_col4, #T_d57bf_row9_col4, #T_d57bf_row10_col4, #T_d57bf_row11_col4, #T_d57bf_row12_col4, #T_d57bf_row13_col4, #T_d57bf_row14_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_d57bf_row0_col5, #T_d57bf_row1_col5, #T_d57bf_row2_col5, #T_d57bf_row3_col5, #T_d57bf_row4_col5, #T_d57bf_row5_col5, #T_d57bf_row6_col5, #T_d57bf_row7_col5, #T_d57bf_row8_col5, #T_d57bf_row9_col5, #T_d57bf_row10_col5, #T_d57bf_row11_col5, #T_d57bf_row12_col5, #T_d57bf_row13_col5, #T_d57bf_row14_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_d57bf">
#   <caption><strong>Data Frame Summary</strong><br>df<br>Dimensions: 32,910 x 15<br>Duplicates: 8</caption>
#   <thead>
#     <tr>
#       <th id="T_d57bf_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_d57bf_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_d57bf_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_d57bf_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_d57bf_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_d57bf_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d57bf_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_d57bf_row0_col1" class="data row0 col1" ><strong>age</strong><br>[int64]</td>
#       <td id="T_d57bf_row0_col2" class="data row0 col2" >Mean (sd) : 40.0 (10.4)<br>min < med < max:<br>17.0 < 38.0 < 98.0<br>IQR (CV) : 15.0 (3.8)</td>
#       <td id="T_d57bf_row0_col3" class="data row0 col3" >75 distinct values</td>
#       <td id="T_d57bf_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_d57bf_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_d57bf_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_d57bf_row1_col1" class="data row1 col1" ><strong>job</strong><br>[object]</td>
#       <td id="T_d57bf_row1_col2" class="data row1 col2" >1. admin.<br>2. blue-collar<br>3. technician<br>4. services<br>5. management<br>6. retired<br>7. entrepreneur<br>8. self-employed<br>9. housemaid<br>10. unemployed<br>11. other</td>
#       <td id="T_d57bf_row1_col3" class="data row1 col3" >8,305 (25.2%)<br>7,430 (22.6%)<br>5,392 (16.4%)<br>3,192 (9.7%)<br>2,343 (7.1%)<br>1,364 (4.1%)<br>1,159 (3.5%)<br>1,098 (3.3%)<br>855 (2.6%)<br>798 (2.4%)<br>974 (3.0%)</td>
#       <td id="T_d57bf_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_d57bf_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_d57bf_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_d57bf_row2_col1" class="data row2 col1" ><strong>marital</strong><br>[object]</td>
#       <td id="T_d57bf_row2_col2" class="data row2 col2" >1. married<br>2. single<br>3. divorced<br>4. unknown</td>
#       <td id="T_d57bf_row2_col3" class="data row2 col3" >19,929 (60.6%)<br>9,245 (28.1%)<br>3,671 (11.2%)<br>65 (0.2%)</td>
#       <td id="T_d57bf_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_d57bf_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_d57bf_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_d57bf_row3_col1" class="data row3 col1" ><strong>education</strong><br>[object]</td>
#       <td id="T_d57bf_row3_col2" class="data row3 col2" >1. university.degree<br>2. high.school<br>3. basic.9y<br>4. professional.course<br>5. basic.4y<br>6. basic.6y<br>7. unknown<br>8. illiterate</td>
#       <td id="T_d57bf_row3_col3" class="data row3 col3" >9,727 (29.6%)<br>7,585 (23.0%)<br>4,818 (14.6%)<br>4,184 (12.7%)<br>3,322 (10.1%)<br>1,863 (5.7%)<br>1,395 (4.2%)<br>16 (0.0%)</td>
#       <td id="T_d57bf_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_d57bf_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_d57bf_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_d57bf_row4_col1" class="data row4 col1" ><strong>default</strong><br>[object]</td>
#       <td id="T_d57bf_row4_col2" class="data row4 col2" >1. no<br>2. unknown<br>3. yes</td>
#       <td id="T_d57bf_row4_col3" class="data row4 col3" >25,975 (78.9%)<br>6,932 (21.1%)<br>3 (0.0%)</td>
#       <td id="T_d57bf_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_d57bf_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_d57bf_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_d57bf_row5_col1" class="data row5 col1" ><strong>housing</strong><br>[object]</td>
#       <td id="T_d57bf_row5_col2" class="data row5 col2" >1. yes<br>2. no<br>3. unknown</td>
#       <td id="T_d57bf_row5_col3" class="data row5 col3" >17,236 (52.4%)<br>14,879 (45.2%)<br>795 (2.4%)</td>
#       <td id="T_d57bf_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_d57bf_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_d57bf_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_d57bf_row6_col1" class="data row6 col1" ><strong>loan</strong><br>[object]</td>
#       <td id="T_d57bf_row6_col2" class="data row6 col2" >1. no<br>2. yes<br>3. unknown</td>
#       <td id="T_d57bf_row6_col3" class="data row6 col3" >27,099 (82.3%)<br>5,016 (15.2%)<br>795 (2.4%)</td>
#       <td id="T_d57bf_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_d57bf_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_d57bf_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_d57bf_row7_col1" class="data row7 col1" ><strong>contact</strong><br>[object]</td>
#       <td id="T_d57bf_row7_col2" class="data row7 col2" >1. cellular<b

# %%
cf.show_categorical_correlation(df, target="y", cols_to_consider=['job', 'education'], figsize=(12,4))

# %%
print('Columns with de-facto missing values:')       
df.columns[df.isin(['unknown']).any()].tolist()
# Out:
# Columns with de-facto missing values:
# ['job', 'marital', 'education', 'default', 'housing', 'loan']

# %% [markdown]
# #### **Initial impressions and take-aways**

# %% [markdown]
# ####  *Attributes and their possible meanings*
#
# <details>
#
# | **Column**    | **Column's meaning (*presumably !!!*)** |
# |---------------|------------------------|
# | age           | Current age of a person |
# | job           | Job category to which person's profession falls into |
# | marital       | Marital Status of a client |
# | education     | Level of education that a contacted person has achieved so far |
# | default       | Column indicating if this person had credit defaults in the past? |
# | housing       | Column indicating whether a client posesses own real estate property? Alternatively, this could also indicate whether a contacted person has an on-going mortgage loan. Not sure about which one is correct (if any)|
# | loan          | Column indicating whether an individual had any active/remaining loans at that moment?|
# | contact       | Phone type that contacted person uses ('cellular', 'telephone') |
# | month         | Month when contact took place |
# | day_of_week   | Weekday when contact took place |
# | duration      | Call duration? (probably in seconds) |
# | campaign      | Number of phone calls made during current campaign? |
# | previous      | Number of phone calls made during previous campgaign?|
# | poutcome      | Outcome of the previous marketing campaign? ('success', 'failure', 'other', 'unknown') |
# | y             | Target column, indicating whether a given person has agreed to make a deposit |
#
# </details>

# %% [markdown]
# #### *Issues and flaws of the original dataset*
#
# <details>
#
# In theory, any dataset can potentially suffer from the following problems that (depending on severity) can seriously limit the ability to make meaninglful prediction:
#
#     - Insufficient sample size
#     - Non-representativeness of training data (i.e. sampling bias)
#     - Non-informative features(ex: irrelevant variables, absence of variation)
#     - Poor-quality content (ex: ambiguity of values, abundance of outliers and/or missing values, noise)
#
# >Is any of those issues is present in this case? Let's explore it.
#
# An initial analysis quickly reveals that this dataset contains (at least) the following flaws and inconsistencies that should be adressed:
#
# 1. All categorical attributes are stored as objects (i.e. text-data).
#
# 2. 8 rows are full duplicates of already existing rows.
#
# 3. Although at first glance, there seem to be no missing values, some columns
# like ```marital```, ```education```, ```housing``` etc. contain value called *unknown*, which in its essense is equivalent to N/A since it does not provide us any useful meaning on its own. Neither can we regard it as category on its own.
#
# 4. Column ```default``` has almost zero variability (hence, not informative). This is indeed a problem, since only few intances of **yes** are neither sufficient for training data nor for making any meaningful judgements. This handicap therefore makes use of ```default``` column meaningless.
#
# 5. Columns ```education``` and ```job``` consists of many categories that despite having the same meaning and describing the same phenomenon, are nevertheless splitted into different categories. I believe this degree of granularity unnecesarily introduces an extra layer of complexity and reduces useful training data size. Yet, it brings no informativeness in practical terms. For instance, does anyone really believe that there is a drastic difference between categories "illeteral", "basic.4y" and "basic.6y"? Is the difference among them really big enough to justify splitting them into different groups? I don't think so. Similarly, don't "blue-collar" and "technician" represent the same job category?
#
# 6. Problems, somewhat similar to those described in previous 2 points also exist in some other columns. For instance, columns ```previous```, ```poutcome```,  ```month``` etc. all seem to be heavily skewed.
#
# 7. In addition to being heavily imbalanced, ```month``` also does not contain two months: "January" and "February". This sort of data incompleteness leads to mutiple issues (if parameter "month" is used for predictions), the biggest being: * What if in the future a campaign is launched in January or February?*
#
# 8. It look like call duration is measured in seconds. But is this level of granularity necessary? Is there a big difference between 120 and 145 seconds for example? Or between 1 and 35 seconds? It might actually be more meaningful to convert those values into minutes to make differences in call durations more obvious.
#
# In short, main problems present in the original version of the dataset can be attributed to:
#  - Presence of outliers
#  - Scarce presence of certain values
#  - Noise caused by over-detalization
#
#
#
# Ideally, all of those issues should be resolved via taking into consideration the bank's underlying context and cicrumstances under which data was collected. But, given that this kind of information is beyond of my reach, the next best thing I can do is to make plausible assumptions and proceed with them, hoping that my guesses resembly the reality close enough. In the later part of this notebook, I will present my approach.
#
# </details>

# %% [markdown]
# Let's plot certain column to visually demonstrate what the problem is

# %%
cf.plot_relative_freq(df, 'month', target='y', figsize=(12, 3))
cf.plot_relative_freq(df, 'day_of_week', target='y', figsize=(12, 3))

# %% [markdown]
# *Short overview of initially discovered flaws and issues associated with features*
#
# Note: It does not mean that the list of issues provided below is exhaustive. There could be more upcoming. But this requires way more in-depth analysis.
#
# <details>
#
# | **Column**    | **Possible issues (minor and big) and risks associated** |
# |---------------|------------------------|
# | age           | presence of outliers |
# | job           | over-granularity, lack of standartized options,  missing values |
# | marital       | Missing values |
# | education     | over-granularity,  missing values |
# | default       | no-variability of data (almost all values are "no"), missing values |
# | housing       | missing values |
# | loan          | missing values |
# | month         | not all months are included, distribution of values is highly skewed |
# | duration      | over-granularity, truncation might be necessary to minimize the effect of outliers |
# | campaign      | truncation might be necessary to minimize the effect of outliers |
# | previous      | imbalanced data, truncation might be necessary to minimize the effect of outliers|
# | poutcome      | imbalanced data |
# | y             | imbalanced data |
#
# </details>

# %% [markdown]
# #### Part II: Fixing flaws and making data more informative
#
# > Remark:  In order to keep this Notebook neat and tidy, I wrapped all cumbersome code into functions and placed them in a separate Python file called ```custom_functions.py```. Feel free to inspect the source file if you are interested in details of code implementations.

# %% [markdown]
# > #### Step 1: Preliminary Data Cleaning

# %%
# Make a copy of the original dataframe to avoid modifying it
df_new = df.copy()

# Replace original values for certain columns
df_new = df_new.replace({'unknown': None})

# Impute N/A using relative frequency method instead of dropping them or using KNN imputation
df_new = cf.probabilistic_imputation(df_new)    # Explain why this approach was chosen

# Convert all string columns to categorical
df_new = cf.convert_to_categorical(df_new, columns='all')

# Replace extermely rare value "illeterate" with the closest value "basic.4years"
df_new['education'] = df_new['education'].replace('illiterate', 'basic.4y')

# Express call duration in minutes and round to the nearest digit
df_new['duration_mins'] = (df_new['duration'] / 60).round().astype(int)

# Drop fully duplicated rows and irrelevant column(s) (which we know exist)
df_new = df_new.drop(columns=['default', 'month', 'duration'])  # Explain why these columns were dropped
df_new = df_new.drop_duplicates()

# %% [markdown]
# > #### Step 2: Making more sense out of features (Feature Engineering)
#
# **Problem Statement**
#
# As already discussed above, certain columns (*especially categorical ones*) suffer from excessive detalization. I suppose this most likely stems from poorly designed data collection process. To be more specific, list of values that a categorical attribute can take is not standardized. Plus, in certain cases responses simply lack, making attribution to a certain category a pure speculation. In any case, whatever the root cause might be, the issue needs to be resolved.
#
# **Proposed Solution**:
#
# I am fully aware of the fact that there are many possible combinations of creating columns from existing ones. In fact, the artistic part of Data Science comes from investing time and effort to discover the best possible option among them.
#
# Here is my approach, that I (*given the limited time and no context regarding sample collection*) have found to be meaningful enough:

# %% [markdown]
# <br>
#
# **Redefine Job feature**
#
# All mappings showing transition logic have been saved into a separate JSON file ```mappings.json```. This approach offers several benefits such as improved code readability and easier maintenance.

# %%
# Load mappings from JSON file
with open('mappings.json', 'r') as f:
    mappings = json.load(f)

education_level_mapping = mappings['education_level_mapping']
job_category_mapping = mappings['job_category_mapping']
income_level_mapping = mappings['income_level_mapping']

# Create the education_level column
df_new['education_level'] = df_new['education'].map(education_level_mapping).astype('category')
# Create the job_category column
df_new['job_type'] = df_new['job'].map(job_category_mapping).astype('category')
# Create the income_level column
df_new['income_level'] = df_new['job'].map(income_level_mapping).astype('category')

# %% [markdown]
# <br>
#
# **Redefine features representing past relationships with clients**

# %%
df_new['was_contacted_before'] = df_new['previous'].apply(lambda previous: True if previous > 0 else False)
df_new['deposited_before'] = df_new['poutcome'].apply(lambda outcome: True if outcome == 'success' else False)

# %%
# Display the summary of the new dataframe
dfSummary(data=df_new, is_collapsible=True)
# Out:
# <button type="button" class = "st-collapsible",
#     id = "btn-4702" onclick = "coll_toggle_4702()">Show Summary - df_new</button>
#     <div class="st-content" id="cont-4702">
#       <style type="text/css">
# #T_97425 thead>tr>th {
#   text-align: left;
# }
# #T_97425_row0_col0, #T_97425_row1_col0, #T_97425_row2_col0, #T_97425_row3_col0, #T_97425_row4_col0, #T_97425_row5_col0, #T_97425_row6_col0, #T_97425_row7_col0, #T_97425_row8_col0, #T_97425_row9_col0, #T_97425_row10_col0, #T_97425_row11_col0, #T_97425_row12_col0, #T_97425_row13_col0, #T_97425_row14_col0, #T_97425_row15_col0, #T_97425_row16_col0, #T_97425_row17_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_97425_row0_col1, #T_97425_row1_col1, #T_97425_row2_col1, #T_97425_row3_col1, #T_97425_row4_col1, #T_97425_row5_col1, #T_97425_row6_col1, #T_97425_row7_col1, #T_97425_row8_col1, #T_97425_row9_col1, #T_97425_row10_col1, #T_97425_row11_col1, #T_97425_row12_col1, #T_97425_row13_col1, #T_97425_row14_col1, #T_97425_row15_col1, #T_97425_row16_col1, #T_97425_row17_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_97425_row0_col2, #T_97425_row1_col2, #T_97425_row2_col2, #T_97425_row3_col2, #T_97425_row4_col2, #T_97425_row5_col2, #T_97425_row6_col2, #T_97425_row7_col2, #T_97425_row8_col2, #T_97425_row9_col2, #T_97425_row10_col2, #T_97425_row11_col2, #T_97425_row12_col2, #T_97425_row13_col2, #T_97425_row14_col2, #T_97425_row15_col2, #T_97425_row16_col2, #T_97425_row17_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_97425_row0_col3, #T_97425_row1_col3, #T_97425_row2_col3, #T_97425_row3_col3, #T_97425_row4_col3, #T_97425_row5_col3, #T_97425_row6_col3, #T_97425_row7_col3, #T_97425_row8_col3, #T_97425_row9_col3, #T_97425_row10_col3, #T_97425_row11_col3, #T_97425_row12_col3, #T_97425_row13_col3, #T_97425_row14_col3, #T_97425_row15_col3, #T_97425_row16_col3, #T_97425_row17_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_97425_row0_col4, #T_97425_row1_col4, #T_97425_row2_col4, #T_97425_row3_col4, #T_97425_row4_col4, #T_97425_row5_col4, #T_97425_row6_col4, #T_97425_row7_col4, #T_97425_row8_col4, #T_97425_row9_col4, #T_97425_row10_col4, #T_97425_row11_col4, #T_97425_row12_col4, #T_97425_row13_col4, #T_97425_row14_col4, #T_97425_row15_col4, #T_97425_row16_col4, #T_97425_row17_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_97425_row0_col5, #T_97425_row1_col5, #T_97425_row2_col5, #T_97425_row3_col5, #T_97425_row4_col5, #T_97425_row5_col5, #T_97425_row6_col5, #T_97425_row7_col5, #T_97425_row8_col5, #T_97425_row9_col5, #T_97425_row10_col5, #T_97425_row11_col5, #T_97425_row12_col5, #T_97425_row13_col5, #T_97425_row14_col5, #T_97425_row15_col5, #T_97425_row16_col5, #T_97425_row17_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_97425">
#   <caption><strong>Data Frame Summary</strong><br>df_new<br>Dimensions: 32,205 x 18<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_97425_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_97425_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_97425_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_97425_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_97425_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_97425_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_97425_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_97425_row0_col1" class="data row0 col1" ><strong>age</strong><br>[int64]</td>
#       <td id="T_97425_row0_col2" class="data row0 col2" >Mean (sd) : 40.1 (10.4)<br>min < med < max:<br>17.0 < 38.0 < 98.0<br>IQR (CV) : 15.0 (3.8)</td>
#       <td id="T_97425_row0_col3" class="data row0 col3" >75 distinct values</td>
#       <td id="T_97425_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_97425_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_97425_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_97425_row1_col1" class="data row1 col1" ><strong>job</strong><br>[category]</td>
#       <td id="T_97425_row1_col2" class="data row1 col2" >1. admin.<br>2. blue-collar<br>3. technician<br>4. services<br>5. management<br>6. retired<br>7. entrepreneur<br>8. self-employed<br>9. housemaid<br>10. unemployed<br>11. other</td>
#       <td id="T_97425_row1_col3" class="data row1 col3" >8,086 (25.1%)<br>7,318 (22.7%)<br>5,299 (16.5%)<br>3,169 (9.8%)<br>2,340 (7.3%)<br>1,361 (4.2%)<br>1,171 (3.6%)<br>1,096 (3.4%)<br>855 (2.7%)<br>798 (2.5%)<br>712 (2.2%)</td>
#       <td id="T_97425_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_97425_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_97425_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_97425_row2_col1" class="data row2 col1" ><strong>marital</strong><br>[category]</td>
#       <td id="T_97425_row2_col2" class="data row2 col2" >1. married<br>2. single<br>3. divorced</td>
#       <td id="T_97425_row2_col3" class="data row2 col3" >19,505 (60.6%)<br>9,051 (28.1%)<br>3,649 (11.3%)</td>
#       <td id="T_97425_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_97425_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_97425_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_97425_row3_col1" class="data row3 col1" ><strong>education</strong><br>[category]</td>
#       <td id="T_97425_row3_col2" class="data row3 col2" >1. university.degree<br>2. high.school<br>3. basic.9y<br>4. professional.course<br>5. basic.4y<br>6. basic.6y</td>
#       <td id="T_97425_row3_col3" class="data row3 col3" >9,854 (30.6%)<br>7,800 (24.2%)<br>4,908 (15.2%)<br>4,284 (13.3%)<br>3,450 (10.7%)<br>1,909 (5.9%)</td>
#       <td id="T_97425_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_97425_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_97425_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_97425_row4_col1" class="data row4 col1" ><strong>housing</strong><br>[category]</td>
#       <td id="T_97425_row4_col2" class="data row4 col2" >1. yes<br>2. no</td>
#       <td id="T_97425_row4_col3" class="data row4 col3" >17,264 (53.6%)<br>14,941 (46.4%)</td>
#       <td id="T_97425_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_97425_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_97425_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_97425_row5_col1" class="data row5 col1" ><strong>loan</strong><br>[category]</td>
#       <td id="T_97425_row5_col2" class="data row5 col2" >1. no<br>2. yes</td>
#       <td id="T_97425_row5_col3" class="data row5 col3" >27,090 (84.1%)<br>5,115 (15.9%)</td>
#       <td id="T_97425_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_97425_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_97425_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_97425_row6_col1" class="data row6 col1" ><strong>contact</strong><br>[category]</td>
#       <td id="T_97425_row6_col2" class="data row6 col2" >1. cellular<br>2. telephone</td>
#       <td id="T_97425_row6_col3" class="data row6 col3" >20,359 (63.2%)<br>11,846 (36.8%)</td>
#       <td id="T_97425_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_97425_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>

# %% [markdown]
# Let's explore our data further to figure out if any further changes are necessary

# %% [markdown]
# #### Analysis of Numeric Features

# %%
sns.histplot(df_new['age'], kde=True)  # Create histogram
plt.show()

# %%
cf.plot_boxplots(df_new, columns=['age', 'duration_mins', 'campaign'], target='y', figsize=(15, 3), subplot_grid_size=(1, 3))

# %%
cf.plot_relative_freq(df_new, 'previous', target='y', figsize=(12, 3))

# %% [markdown]
# ##### Key Observations
# <details>
#
# The boxplots reveal the following patterns:
#
# 1. **Age**:
#     - Age distribution is relatively similar for both groups, with a slight skew towards younger individuals agreeing to make a deposit.
#     - Outliers seem to be common in both groups.
#
# 2. **Contacts during current compaign**:
#     - Higher number of phone call during the current campaign may not necessarily lead to a positive outcome. Moreover, there are more outliers in the "no" group, suggesting that after some point repeated simply lose their effectiveness.
#
# 3. **Previous Contact attempts**:
#     - The number of contacts during previous campaigns shows to be associated with minor positive influence over the 'yes' group. This indicates that previous contact history might to some degree have a positive influence on the likelihood of agreeing to a deposit.
#
# 4. **Call Duration (in minutes)**:
#     - Longer calls seem to positive affect one's willingness to deposit, suggesting that engagement during the call is a critical factor.
#
# </details>

# %%
df_new = cf.truncate_values(df_new, 'age', lower=20, upper=70)
df_new = cf.truncate_values(df_new, 'duration_mins', lower=0, upper=20)
df_new = cf.truncate_values(df_new, 'campaign', lower=0, upper=10)
df_new = cf.truncate_values(df_new, 'previous', lower=0, upper=3)

# %% [markdown]
# ### Assessment of Caterorical features
#
# Similar to boxplots, barplots provide a visual representation of the distribution of categorical features segmented by the target variable 'y'. This helps in understanding how these categorical features vary between individuals who agreed to make a deposit ('yes') and those who did not ('no').

# %% [markdown]
# * Relationship between the willingness to deposit and current financial situation

# %%
cf.show_categorical_correlation(
    df_new,
    target='y', 
    cols_to_consider=['housing', 'loan'], 
    figsize=(9, 3),    
    show_details=False, 
    annotate=True
)

# %% [markdown]
# Key finding: Presence of a real estate (or mortgage loan) or any form of other loan seem to have zero to no effect on one's decision to deposit money. Hence we can omit those variable from equation.

# %%
df_new = df_new.drop(columns=['housing', 'loan'])

# %% [markdown]
# * Relationship between the willingness to deposit and people's social status

# %%
cf.show_categorical_correlation(
    df_new,
    target='y', 
    cols_to_consider=['marital', 'education', 'education_level', 'job_type', 'job', 'income_level'], 
    figsize=(15, 8),
    #subplot_grid_size=(1, 4),
    show_details=False, 
    annotate=True
)

# %% [markdown]
# Key finding: Social factors seem to make difference on one's decision to deposit
#
# * Relationship between the willingness to deposit and other factors

# %%
cf.show_categorical_correlation(
    df_new,
    target='y', 
    cols_to_consider=['contact','poutcome', 'previous', 'deposited_before', 'was_contacted_before'], 
    figsize=(14, 6),
    #subplot_grid_size=(1, 3),
    show_details=False, 
    annotate=True
)

# %% [markdown]
# Key findings:
# * Looks like there is an association between the outcome of the past campaigns and the likelihood of depositing in the future

# %% [markdown]
# > Now, once data is believed to be more or less cleaned, let's save a new version dataframe to a local file

# %%
# Drop possible duplicates and view table once again
df_new = df_new.drop_duplicates()
dfSummary(df_new, is_collapsible=True)
# Out:
# <button type="button" class = "st-collapsible",
#     id = "btn-5921" onclick = "coll_toggle_5921()">Show Summary - df_new</button>
#     <div class="st-content" id="cont-5921">
#       <style type="text/css">
# #T_1e0e1 thead>tr>th {
#   text-align: left;
# }
# #T_1e0e1_row0_col0, #T_1e0e1_row1_col0, #T_1e0e1_row2_col0, #T_1e0e1_row3_col0, #T_1e0e1_row4_col0, #T_1e0e1_row5_col0, #T_1e0e1_row6_col0, #T_1e0e1_row7_col0, #T_1e0e1_row8_col0, #T_1e0e1_row9_col0, #T_1e0e1_row10_col0, #T_1e0e1_row11_col0, #T_1e0e1_row12_col0, #T_1e0e1_row13_col0, #T_1e0e1_row14_col0, #T_1e0e1_row15_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_1e0e1_row0_col1, #T_1e0e1_row1_col1, #T_1e0e1_row2_col1, #T_1e0e1_row3_col1, #T_1e0e1_row4_col1, #T_1e0e1_row5_col1, #T_1e0e1_row6_col1, #T_1e0e1_row7_col1, #T_1e0e1_row8_col1, #T_1e0e1_row9_col1, #T_1e0e1_row10_col1, #T_1e0e1_row11_col1, #T_1e0e1_row12_col1, #T_1e0e1_row13_col1, #T_1e0e1_row14_col1, #T_1e0e1_row15_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_1e0e1_row0_col2, #T_1e0e1_row1_col2, #T_1e0e1_row2_col2, #T_1e0e1_row3_col2, #T_1e0e1_row4_col2, #T_1e0e1_row5_col2, #T_1e0e1_row6_col2, #T_1e0e1_row7_col2, #T_1e0e1_row8_col2, #T_1e0e1_row9_col2, #T_1e0e1_row10_col2, #T_1e0e1_row11_col2, #T_1e0e1_row12_col2, #T_1e0e1_row13_col2, #T_1e0e1_row14_col2, #T_1e0e1_row15_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_1e0e1_row0_col3, #T_1e0e1_row1_col3, #T_1e0e1_row2_col3, #T_1e0e1_row3_col3, #T_1e0e1_row4_col3, #T_1e0e1_row5_col3, #T_1e0e1_row6_col3, #T_1e0e1_row7_col3, #T_1e0e1_row8_col3, #T_1e0e1_row9_col3, #T_1e0e1_row10_col3, #T_1e0e1_row11_col3, #T_1e0e1_row12_col3, #T_1e0e1_row13_col3, #T_1e0e1_row14_col3, #T_1e0e1_row15_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_1e0e1_row0_col4, #T_1e0e1_row1_col4, #T_1e0e1_row2_col4, #T_1e0e1_row3_col4, #T_1e0e1_row4_col4, #T_1e0e1_row5_col4, #T_1e0e1_row6_col4, #T_1e0e1_row7_col4, #T_1e0e1_row8_col4, #T_1e0e1_row9_col4, #T_1e0e1_row10_col4, #T_1e0e1_row11_col4, #T_1e0e1_row12_col4, #T_1e0e1_row13_col4, #T_1e0e1_row14_col4, #T_1e0e1_row15_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_1e0e1_row0_col5, #T_1e0e1_row1_col5, #T_1e0e1_row2_col5, #T_1e0e1_row3_col5, #T_1e0e1_row4_col5, #T_1e0e1_row5_col5, #T_1e0e1_row6_col5, #T_1e0e1_row7_col5, #T_1e0e1_row8_col5, #T_1e0e1_row9_col5, #T_1e0e1_row10_col5, #T_1e0e1_row11_col5, #T_1e0e1_row12_col5, #T_1e0e1_row13_col5, #T_1e0e1_row14_col5, #T_1e0e1_row15_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_1e0e1">
#   <caption><strong>Data Frame Summary</strong><br>df_new<br>Dimensions: 31,192 x 16<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_1e0e1_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_1e0e1_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_1e0e1_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_1e0e1_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_1e0e1_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_1e0e1_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1e0e1_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_1e0e1_row0_col1" class="data row0 col1" ><strong>age</strong><br>[int64]</td>
#       <td id="T_1e0e1_row0_col2" class="data row0 col2" >Mean (sd) : 40.1 (10.2)<br>min < med < max:<br>20.0 < 38.0 < 70.0<br>IQR (CV) : 15.0 (3.9)</td>
#       <td id="T_1e0e1_row0_col3" class="data row0 col3" >51 distinct values</td>
#       <td id="T_1e0e1_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_1e0e1_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_1e0e1_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_1e0e1_row1_col1" class="data row1 col1" ><strong>job</strong><br>[category]</td>
#       <td id="T_1e0e1_row1_col2" class="data row1 col2" >1. admin.<br>2. blue-collar<br>3. technician<br>4. services<br>5. management<br>6. retired<br>7. entrepreneur<br>8. self-employed<br>9. housemaid<br>10. unemployed<br>11. other</td>
#       <td id="T_1e0e1_row1_col3" class="data row1 col3" >7,698 (24.7%)<br>7,067 (22.7%)<br>5,117 (16.4%)<br>3,114 (10.0%)<br>2,288 (7.3%)<br>1,333 (4.3%)<br>1,156 (3.7%)<br>1,083 (3.5%)<br>846 (2.7%)<br>788 (2.5%)<br>702 (2.3%)</td>
#       <td id="T_1e0e1_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_1e0e1_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_1e0e1_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_1e0e1_row2_col1" class="data row2 col1" ><strong>marital</strong><br>[category]</td>
#       <td id="T_1e0e1_row2_col2" class="data row2 col2" >1. married<br>2. single<br>3. divorced</td>
#       <td id="T_1e0e1_row2_col3" class="data row2 col3" >18,842 (60.4%)<br>8,754 (28.1%)<br>3,596 (11.5%)</td>
#       <td id="T_1e0e1_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_1e0e1_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_1e0e1_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_1e0e1_row3_col1" class="data row3 col1" ><strong>education</strong><br>[category]</td>
#       <td id="T_1e0e1_row3_col2" class="data row3 col2" >1. university.degree<br>2. high.school<br>3. basic.9y<br>4. professional.course<br>5. basic.4y<br>6. basic.6y</td>
#       <td id="T_1e0e1_row3_col3" class="data row3 col3" >9,439 (30.3%)<br>7,606 (24.4%)<br>4,760 (15.3%)<br>4,148 (13.3%)<br>3,366 (10.8%)<br>1,873 (6.0%)</td>
#       <td id="T_1e0e1_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_1e0e1_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_1e0e1_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_1e0e1_row4_col1" class="data row4 col1" ><strong>contact</strong><br>[category]</td>
#       <td id="T_1e0e1_row4_col2" class="data row4 col2" >1. cellular<br>2. telephone</td>
#       <td id="T_1e0e1_row4_col3" class="data row4 col3" >19,617 (62.9%)<br>11,575 (37.1%)</td>
#       <td id="T_1e0e1_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_1e0e1_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_1e0e1_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_1e0e1_row5_col1" class="data row5 col1" ><strong>day_of_week</strong><br>[category]</td>
#       <td id="T_1e0e1_row5_col2" class="data row5 col2" >1. mon<br>2. thu<br>3. wed<br>4. tue<br>5. fri</td>
#       <td id="T_1e0e1_row5_col3" class="data row5 col3" >6,484 (20.8%)<br>6,466 (20.7%)<br>6,158 (19.7%)<br>6,095 (19.5%)<br>5,989 (19.2%)</td>
#       <td id="T_1e0e1_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_1e0e1_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_1e0e1_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_1e0e1_row6_col1" class="data row6 col1" ><strong>campaign</strong><br>[int64]</td>
#       <td id="T_1e0e1_row6_col2" class="data row6 col2" >Mean (sd) : 2.5 (2.1)<br>min < med < max:<br>1.0 < 2.0 < 10.0<br>IQR (CV) : 2.0 (1.2)</td>
#       <td id="T_1e0e1_row6_col3" class="data row6 col3" >10 distinct values</td>
#       <td id="T_1e0e1_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_1e0e1_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_1e0e1_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_1e0e1_row7_col1" cla

# %%
# Move the 'y' column to the end
df_new = df_new[[col for col in df_new.columns if col != 'y'] + ['y']]
df_new.to_csv('data/cleaned_train_file.csv', index=False)

# %% [markdown]
# ### End of EDA Part
# <hr>

# %%
test_df = pd.read_csv("data/cleaned_train_file.csv")

dfSummary(test_df, is_collapsible=True)
# Out:
# <button type="button" class = "st-collapsible",
#     id = "btn-1250" onclick = "coll_toggle_1250()">Show Summary - test_df</button>
#     <div class="st-content" id="cont-1250">
#       <style type="text/css">
# #T_36864 thead>tr>th {
#   text-align: left;
# }
# #T_36864_row0_col0, #T_36864_row1_col0, #T_36864_row2_col0, #T_36864_row3_col0, #T_36864_row4_col0, #T_36864_row5_col0, #T_36864_row6_col0, #T_36864_row7_col0, #T_36864_row8_col0, #T_36864_row9_col0, #T_36864_row10_col0, #T_36864_row11_col0, #T_36864_row12_col0, #T_36864_row13_col0, #T_36864_row14_col0, #T_36864_row15_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_36864_row0_col1, #T_36864_row1_col1, #T_36864_row2_col1, #T_36864_row3_col1, #T_36864_row4_col1, #T_36864_row5_col1, #T_36864_row6_col1, #T_36864_row7_col1, #T_36864_row8_col1, #T_36864_row9_col1, #T_36864_row10_col1, #T_36864_row11_col1, #T_36864_row12_col1, #T_36864_row13_col1, #T_36864_row14_col1, #T_36864_row15_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_36864_row0_col2, #T_36864_row1_col2, #T_36864_row2_col2, #T_36864_row3_col2, #T_36864_row4_col2, #T_36864_row5_col2, #T_36864_row6_col2, #T_36864_row7_col2, #T_36864_row8_col2, #T_36864_row9_col2, #T_36864_row10_col2, #T_36864_row11_col2, #T_36864_row12_col2, #T_36864_row13_col2, #T_36864_row14_col2, #T_36864_row15_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_36864_row0_col3, #T_36864_row1_col3, #T_36864_row2_col3, #T_36864_row3_col3, #T_36864_row4_col3, #T_36864_row5_col3, #T_36864_row6_col3, #T_36864_row7_col3, #T_36864_row8_col3, #T_36864_row9_col3, #T_36864_row10_col3, #T_36864_row11_col3, #T_36864_row12_col3, #T_36864_row13_col3, #T_36864_row14_col3, #T_36864_row15_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_36864_row0_col4, #T_36864_row1_col4, #T_36864_row2_col4, #T_36864_row3_col4, #T_36864_row4_col4, #T_36864_row5_col4, #T_36864_row6_col4, #T_36864_row7_col4, #T_36864_row8_col4, #T_36864_row9_col4, #T_36864_row10_col4, #T_36864_row11_col4, #T_36864_row12_col4, #T_36864_row13_col4, #T_36864_row14_col4, #T_36864_row15_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_36864_row0_col5, #T_36864_row1_col5, #T_36864_row2_col5, #T_36864_row3_col5, #T_36864_row4_col5, #T_36864_row5_col5, #T_36864_row6_col5, #T_36864_row7_col5, #T_36864_row8_col5, #T_36864_row9_col5, #T_36864_row10_col5, #T_36864_row11_col5, #T_36864_row12_col5, #T_36864_row13_col5, #T_36864_row14_col5, #T_36864_row15_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_36864">
#   <caption><strong>Data Frame Summary</strong><br>test_df<br>Dimensions: 31,192 x 16<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_36864_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_36864_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_36864_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_36864_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_36864_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_36864_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_36864_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_36864_row0_col1" class="data row0 col1" ><strong>age</strong><br>[int64]</td>
#       <td id="T_36864_row0_col2" class="data row0 col2" >Mean (sd) : 40.1 (10.2)<br>min < med < max:<br>20.0 < 38.0 < 70.0<br>IQR (CV) : 15.0 (3.9)</td>
#       <td id="T_36864_row0_col3" class="data row0 col3" >51 distinct values</td>
#       <td id="T_36864_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_36864_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_36864_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_36864_row1_col1" class="data row1 col1" ><strong>job</strong><br>[object]</td>
#       <td id="T_36864_row1_col2" class="data row1 col2" >1. admin.<br>2. blue-collar<br>3. technician<br>4. services<br>5. management<br>6. retired<br>7. entrepreneur<br>8. self-employed<br>9. housemaid<br>10. unemployed<br>11. other</td>
#       <td id="T_36864_row1_col3" class="data row1 col3" >7,698 (24.7%)<br>7,067 (22.7%)<br>5,117 (16.4%)<br>3,114 (10.0%)<br>2,288 (7.3%)<br>1,333 (4.3%)<br>1,156 (3.7%)<br>1,083 (3.5%)<br>846 (2.7%)<br>788 (2.5%)<br>702 (2.3%)</td>
#       <td id="T_36864_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_36864_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_36864_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_36864_row2_col1" class="data row2 col1" ><strong>marital</strong><br>[object]</td>
#       <td id="T_36864_row2_col2" class="data row2 col2" >1. married<br>2. single<br>3. divorced</td>
#       <td id="T_36864_row2_col3" class="data row2 col3" >18,842 (60.4%)<br>8,754 (28.1%)<br>3,596 (11.5%)</td>
#       <td id="T_36864_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_36864_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_36864_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_36864_row3_col1" class="data row3 col1" ><strong>education</strong><br>[object]</td>
#       <td id="T_36864_row3_col2" class="data row3 col2" >1. university.degree<br>2. high.school<br>3. basic.9y<br>4. professional.course<br>5. basic.4y<br>6. basic.6y</td>
#       <td id="T_36864_row3_col3" class="data row3 col3" >9,439 (30.3%)<br>7,606 (24.4%)<br>4,760 (15.3%)<br>4,148 (13.3%)<br>3,366 (10.8%)<br>1,873 (6.0%)</td>
#       <td id="T_36864_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_36864_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_36864_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_36864_row4_col1" class="data row4 col1" ><strong>contact</strong><br>[object]</td>
#       <td id="T_36864_row4_col2" class="data row4 col2" >1. cellular<br>2. telephone</td>
#       <td id="T_36864_row4_col3" class="data row4 col3" >19,617 (62.9%)<br>11,575 (37.1%)</td>
#       <td id="T_36864_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_36864_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_36864_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_36864_row5_col1" class="data row5 col1" ><strong>day_of_week</strong><br>[object]</td>
#       <td id="T_36864_row5_col2" class="data row5 col2" >1. mon<br>2. thu<br>3. wed<br>4. tue<br>5. fri</td>
#       <td id="T_36864_row5_col3" class="data row5 col3" >6,484 (20.8%)<br>6,466 (20.7%)<br>6,158 (19.7%)<br>6,095 (19.5%)<br>5,989 (19.2%)</td>
#       <td id="T_36864_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_36864_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_36864_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_36864_row6_col1" class="data row6 col1" ><strong>campaign</strong><br>[int64]</td>
#       <td id="T_36864_row6_col2" class="data row6 col2" >Mean (sd) : 2.5 (2.1)<br>min < med < max:<br>1.0 < 2.0 < 10.0<br>IQR (CV) : 2.0 (1.2)</td>
#       <td id="T_36864_row6_col3" class="data row6 col3" >10 distinct values</td>
#       <td id="T_36864_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_36864_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_36864_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_36864_row7_col1" class="data
